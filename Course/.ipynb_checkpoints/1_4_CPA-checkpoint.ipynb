# %% [markdown]
# # 相关能量分析（CPA）介绍
# 这里以AES算法为例来介绍CPA

# %% [markdown]
# ---
# ## AES算法简介
# AES是由美国国家标准与技术研究院（NIST）在2001年发布的，旨在取代早期的DES标准，提供更高安全性的加密方法。AES是一种对称加密算法,它支持128位、192位和256位的密钥长度，对应的轮数为10，12，14轮。

# %% [markdown]
# ### AES工作原理
# AES算法通过多轮次的置换-置换网络（SPN）结构来实现加密过程，在第一轮之前，AES先将明文与白化密钥相异或。每轮操作包括以下四个步骤（最后一轮不做列混合）：
#
# - 字节替换（SubBytes）：使用S盒进行非线性置换，增加数据混淆。
# - 行移位（ShiftRows）：不同行进行循环左移，进一步扩散数据。
# - 列混合（MixColumns）：除最后一轮外，使用固定矩阵进行乘法运算，混淆数据。
# - 轮密钥加（AddRoundKey）：将轮密钥与数据块进行异或运算，融入密钥信息

# %% [markdown]
# 字节替换的示例图如下：
#
# ![AES字节替换](http://5b0988e595225.cdn.sohucs.com/images/20171027/500ec31d0b9b4710826fc05a3de699db.png "AES S盒")

# %% [markdown]
# 行移位示意图：
#
# ![AES行移位](http://5b0988e595225.cdn.sohucs.com/images/20171027/2fd25929f10d427f9c944b4f8ea4eee7.jpeggg)

# %% [markdown]
# 列混合示意图：
#
# ![AES列混合](http://5b0988e595225.cdn.sohucs.com/images/20171027/d6b8627a54e241acb546ed9b83f00be7.jpeg)

# %% [markdown]
# 轮密钥异或示意图：
#
# ![AES轮密钥异或](http://5b0988e595225.cdn.sohucs.com/images/20171027/398a34643dc84307a5737eadb40aaeca.jpeg)

# %% [markdown]
# ## CPA分析的位置

# %% [markdown]
# 由于我们的分析对象是软件实现的AES，为了便于进行CPA分析的演示和说明，我们以第一轮字节替换层的输出为对象进行分析，使用的泄漏模型为汉明重量模型，即计算第一轮S盒的输出汉明重量HW$(S(p \oplus k))$与曲线的相关系数。其中$p$为明文的一个字节，$k$为猜测的白化密钥的一个字节。

# %% [markdown]
# 相关系数是衡量两个变量之间线性关系强度和方向的统计量。在CPA（Correlation Power Analysis）攻击中，通常使用皮尔逊相关系数（Pearson Correlation Coefficient）来衡量实际测量的能量迹与根据猜测密钥计算的预期功耗之间的相关性。

# %% [markdown]
# 皮尔逊相关系数的计算公式如下：
#
# $$
#         r_{i,j} = \frac{\sum_{d=1}^{D} (h_{d,i} - \bar{h}_i)(t_{d,j} - \bar{t}_j)}{\sqrt{\sum_{d=1}^{D} (h_{d,i} - \bar{h}_i)^2 \sum_{d=1}^{D} (t_{d,j} - \bar{t}_j)^2}}
# $$

# %% [markdown]
# 其中：
# * $r_{i,j}$ 是相关系数。
# * $ h_{d,i} $ 是第 $ d $ 个样本在第 $ i $ 个猜测密钥下的汉明重量。
# * $ \bar{h}_i $ 是第 $ i $ 个猜测密钥下所有样本的汉明重量的平均值。
# * $ t_{d,j} $ 是第 $ d $ 个能量迹在第 $ j $ 个时间点的功耗值。
# * $ \bar{t}_j $ 是所有能量迹在第 $ j $ 个时间点的功耗值的平均值。
# * $ D $ 是样本数量或时间点的数量。

# %% [markdown]
# 相关系数的值范围在 -1 到 1 之间，其中：
# * 1 表示完全正相关，即随着一个变量的增加，另一个变量也增加。
# * -1 表示完全负相关，即随着一个变量的增加，另一个变量减少。
# * 0 表示没有线性相关。

# %% [markdown]
# 在CPA攻击中，攻击者会计算每个猜测密钥的相关系数，并寻找最高值，这个最高值对应的猜测密钥很可能是正确的密钥。

# %% [markdown]
# ### NUT的AES实现

# %% [markdown]
# NUT的无防护的AES实现使用的是mbedTLS的查小表实现。对于这种实现，对其进行CPA分析时，与教科书AES实现（即前面所讲的AES实现）是一样的。

# %% [markdown]
# ### 能量迹采集
# 采集的过程见参 [采集过程](temp.ipynb)

# %% [markdown]
# 采集出来的能量迹曲线如下图所示

# %%
import cracknuts as cn
# 引入波形文件数据集对象
from cracknuts.trace.trace import ScarrTraceDataset
# 显示曲线分析面板
tap_cracker1_fix = cn.panel_trace()

# 加载波形文件
scarr_trace_dataset_cracker1 = ScarrTraceDataset.load("../traces/sw_aes_200.zarr")
# 将数据集配置到波形显示面板
tap_cracker1_fix.set_trace_dataset(scarr_trace_dataset_cracker1)
# 显示第二通道的前十条曲线
tap_cracker1_fix.show_trace[0, 0]

# %%
tap_cracker1_fix
# Out:
# TracePanelWidget(chart_size={'width': 0, 'height': 0}, language='zh', overview_select_range=(0, 0), overview_t…

# %% [markdown]
# ## CPA分析展示

# %% [markdown]
# > 使用scarr库（https://github.com/decryptofy/scarr.git） 来进行AES的CPA分析展示。
# > python版本要求：python 3.10以上
# > 为了便于展示，我们有可能会对scarr库进行修改，因此请从如下fork的地址进行下载安装：
# > git clone https://github.com/cracknuts-team-admin/scarr.git
# > cd scarr
# > pip install .

# %%
from scarr.engines.cpa import CPA as cpa
from scarr.file_handling.trace_handler import TraceHandler as th
from scarr.model_values.sbox_weight import SboxWeight
from scarr.container.container import Container, ContainerOptions
import numpy as np

# %% [markdown]
# 指定要分析的能量迹文件，该曲线来自于CrackS1, nut_stm32f103：

# %%
# dataset_name = 'aes_nut1.zarr'
dataset_name = '../traces/sw_aes_200.zarr'

# %%
handler2 = th(fileName=dataset_name)
# Out:
# opened zarr file  ../traces/sw_aes_200.zarr

# %% [markdown]
# 分析模型为汉明重量模型：

# %%
model = SboxWeight() 
engine2 = cpa(model)

# %% [markdown]
# 对所有16个密钥字节进行分析：

# %%
container2 = Container(options=ContainerOptions(engine=engine2, handler=handler2), model_positions = [x for x in range(16)])
container2.run()

# %% [markdown]
# 获取所计算出来的相关系数矩阵，存于变量results2中：

# %%
results2 = container2.engine.get_result()

# %% [markdown]
# 获取每个字节最大相关系数所对应的密钥，存于results中：

# %%
results = np.squeeze(engine2.get_candidate())

# %% [markdown]
# results存储的是各个字节的密钥的计算结果，我们将其以16进制打印出来，可见是正确的密钥。

# %%
' '.join(f"{x:02x}" for x in results)
# Out:
# '11 22 33 44 55 66 77 88 99 00 aa bb cc dd ee ff'

# %% [markdown]
# 将第0字节所对应的相关系数矩阵取出，并存于变量result中，以方便后面的演示：

# %%
result = np.squeeze(results2)
result = result[0]

# %%
candidate = [None for _ in range(result.shape[0])]

for i in range(result.shape[0]):
    candidate[i] = np.unravel_index(np.abs(result[i, :]).argmax(), result[i, :].shape[0:])[0]

# %%
candidates = np.empty(256, dtype=np.float64)
for k in range(256):
    candidates[k] = result[k,candidate[k]]
ck = np.abs(candidates).argmax()

# %% [markdown]
# 把第0字节相关性最大的前10个相关系数及其对应的密钥猜测值打印出来。这10个密钥即为这个字节的前10个密钥候选值。一般来说，第1个候选值所对应的相关系数如果和第2候选值相差较大，我们便认为它是正确的密钥。

# %%
for _i in range(0, 10):
    print('第',str(_i+1),'个候选值：',hex(np.abs(candidates).argsort()[::-1][_i]),'， 对应的相关系数为：',str(candidates[np.abs(candidates).argsort()[::-1][_i]]))
# Out:
# 第 1 个候选值： 0x11 ， 对应的相关系数为： 0.6789133548736572
# 第 2 个候选值： 0xe1 ， 对应的相关系数为： 0.36615246534347534
# 第 3 个候选值： 0x58 ， 对应的相关系数为： -0.34870395064353943
# 第 4 个候选值： 0xe6 ， 对应的相关系数为： -0.3310008943080902
# 第 5 个候选值： 0x63 ， 对应的相关系数为： -0.3274860084056854
# 第 6 个候选值： 0x98 ， 对应的相关系数为： 0.30935850739479065
# 第 7 个候选值： 0x16 ， 对应的相关系数为： -0.30923327803611755
# 第 8 个候选值： 0x8e ， 对应的相关系数为： -0.30905696749687195
# 第 9 个候选值： 0xd1 ， 对应的相关系数为： -0.3069278597831726
# 第 10 个候选值： 0x22 ， 对应的相关系数为： 0.3026044964790344

# %% [markdown]
# 把第0个字节的256个密钥猜测下的相关系数曲线画出来。正确密钥用红色画出，其它密钥用灰色画出。可以看出正确密钥对应的相关系数曲线存在最明显的尖峰。

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_correlation_peaks(result_bytes, bytes_index, the_key):
    
    x = np.arange(0, 5000)
    
    fig, ax = plt.subplots(figsize=(20, 4))
    
    for i in range(256):
        if i == the_key:
            continue
        ax.plot(x, result_bytes[bytes_index, i, :5000], color='gray', linewidth=0.5, alpha=0.3)
            
    ax.plot(x, result_bytes[bytes_index, the_key, :5000], color='red', linewidth=1.0)
    
    ax.grid(True, linestyle='--', alpha=0.3)
    plt.tight_layout()
    
    plt.show()

# %%
plot_correlation_peaks(np.squeeze(results2), 0, 0x11)

# %% [markdown]
# 把第1个字节的256个密钥猜测下的相关系数曲线画出来。正确密钥用红色画出，其它密钥用灰色画出。可以看出正确密钥对应的相关系数曲线存在最明显的尖峰。

# %%
plot_correlation_peaks(np.squeeze(results2), 1, 0x22)

# %% [markdown]
# 把第2个字节的256个密钥猜测下的相关系数曲线画出来。正确密钥用红色画出，其它密钥用灰色画出。可以看出正确密钥对应的相关系数曲线存在最明显的尖峰。

# %%
plot_correlation_peaks(np.squeeze(results2), 2, 0x33)

# %% [markdown]
# 把所有16个字节正确密钥对应的相关系数曲线画出来，以便观察它们的时间点。

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5000)

fig, ax = plt.subplots(figsize=(20, 4))

r = np.squeeze(results2)

ax.plot(x, r[0, 0x11, :5000], linewidth=1.0, label='0x11')
ax.plot(x, r[1, 0x22, :5000], linewidth=1.0, label='0x22')
ax.plot(x, r[2, 0x33, :5000], linewidth=1.0, label='0x33')
ax.plot(x, r[3, 0x44, :5000], linewidth=1.0, label='0x44')
ax.plot(x, r[4, 0x55, :5000], linewidth=1.0, label='0x55')
ax.plot(x, r[5, 0x66, :5000], linewidth=1.0, label='0x66')
ax.plot(x, r[6, 0x77, :5000], linewidth=1.0, label='0x77')
ax.plot(x, r[7, 0x88, :5000], linewidth=1.0, label='0x88')
ax.plot(x, r[8, 0x99, :5000], linewidth=1.0, label='0x99')
ax.plot(x, r[9, 0x00, :5000], linewidth=1.0, label='0x00')
ax.plot(x, r[10, 0xaa, :5000], linewidth=1.0, label='0xaa')
ax.plot(x, r[11, 0xbb, :5000], linewidth=1.0, label='0xbb')
ax.plot(x, r[12, 0xcc, :5000], linewidth=1.0, label='0xcc')
ax.plot(x, r[13, 0xdd, :5000], linewidth=1.0, label='0xdd')
ax.plot(x, r[14, 0xee, :5000], linewidth=1.0, label='0xee')
ax.plot(x, r[15, 0xff, :5000], linewidth=1.0, label='0xff')

ax.grid(True, linestyle='--', alpha=0.3)
ax.legend(loc='upper right', fontsize='small', ncol=2)

plt.tight_layout()

# 显示图像
plt.show()
